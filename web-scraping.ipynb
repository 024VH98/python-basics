# %%
from bs4 import BeautifulSoup
import requests

# %%
html="<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body></html>"

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Page Title
#   </title>
#  </head>
#  <body>
#   <h3>
#    <b id="boldest">
#     Lebron James
#    </b>
#   </h3>
#   <p>
#    Salary: $ 92,000,000
#   </p>
#   <h3>
#    Stephen Curry
#   </h3>
#   <p>
#    Salary: $85,000, 000
#   </p>
#   <h3>
#    Kevin Durant
#   </h3>
#   <p>
#    Salary: $73,200, 000
#   </p>
#  </body>
# </html>

# %%
tag_object = soup.title
print(f'tag object: {tag_object}')
# Out:
# tag object: <title>Page Title</title>

# %%
print("tag object type:",type(tag_object))
# Out:
# tag object type: <class 'bs4.element.Tag'>

# %%
tag_object=soup.h3
tag_object
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
tag_child =tag_object.b
tag_child
# Out:
# <b id="boldest">Lebron James</b>

# %%
parent_tag=tag_child.parent
parent_tag
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
tag_object
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
tag_object.parent
# Out:
# <body><h3><b id="boldest">Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body>

# %%
sibling_1=tag_object.next_sibling
sibling_1
# Out:
# <p> Salary: $ 92,000,000 </p>

# %%
sibling_2=sibling_1.next_sibling
sibling_2
# Out:
# <h3> Stephen Curry</h3>

# %%
sibling_3 = sibling_2.next_sibling
sibling_3
# Out:
# <p> Salary: $85,000, 000 </p>

# %%
tag_child['id']
# Out:
# 'boldest'

# %%
tag_child.attrs
# Out:
# {'id': 'boldest'}

# %%
tag_child.get('id')
# Out:
# 'boldest'

# %%
tag_string = tag_child.string
tag_string
# Out:
# 'Lebron James'

# %%
type(tag_string)
# Out:
# bs4.element.NavigableString

# %%
unicode_string = str(tag_string)
unicode_string
# Out:
# 'Lebron James'

# %%
table="<table><tr><td id='flight'>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a></td><td>300 kg</td></tr><tr><td>2</td><td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td><td>80 kg</td></tr></table>"
table_bs = BeautifulSoup(table, 'html.parser')

# %%
table_rows = table_bs.find_all('tr')
table_rows
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr>]

# %%
first_row = table_rows[0]
first_row
# Out:
# <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>

# %%
print(type(first_row))
# Out:
# <class 'bs4.element.Tag'>

# %%
first_row.td
# Out:
# <td id="flight">Flight No</td>

# %%
for i, row in enumerate(table_rows):
    print(f'Row: {i}')
    cells = row.find_all('td')
    for j, cell in enumerate(cells):
        print(f'Column: {j}, Cell: {cell}')
# Out:
# Row: 0
# Column: 0, Cell: <td id="flight">Flight No</td>
# Column: 1, Cell: <td>Launch site</td>
# Column: 2, Cell: <td>Payload mass</td>
# Row: 1
# Column: 0, Cell: <td>1</td>
# Column: 1, Cell: <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td>
# Column: 2, Cell: <td>300 kg</td>
# Row: 2
# Column: 0, Cell: <td>2</td>
# Column: 1, Cell: <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>
# Column: 2, Cell: <td>94 kg</td>
# Row: 3
# Column: 0, Cell: <td>3</td>
# Column: 1, Cell: <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td>
# Column: 2, Cell: <td>80 kg</td>

# %%
list_input = table_bs.find_all(name=['tr', 'td'])
list_input
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr>,
#  <td>1</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td>,
#  <td>300 kg</td>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <td>2</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>,
#  <td>94 kg</td>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr>,
#  <td>3</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td>,
#  <td>80 kg</td>]

# %%
table_bs.find_all(id='flight')
# Out:
# [<td id="flight">Flight No</td>]

# %%
list_input=table_bs.find_all(href="https://en.wikipedia.org/wiki/Florida")
list_input
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a>]

# %%
table_bs.find_all(href=True)
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a>,
#  <a href="https://en.wikipedia.org/wiki/Texas">Texas</a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a>]

# %%
table_bs.find_all(name=['a'], href=False)
# Out:
# [<a></a>, <a> </a>]

# %%
table_bs.find_all(lambda tag: tag.name == "a" and not tag.has_attr("href"))
# Out:
# [<a></a>, <a> </a>]

# %%
table_bs.find_all(lambda tag: tag.name != "a" and not tag.find('a'))
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <td>1</td>,
#  <td>300 kg</td>,
#  <td>2</td>,
#  <td>94 kg</td>,
#  <td>3</td>,
#  <td>80 kg</td>]

# %%
table_bs.find_all(string="Florida")
# Out:
# ['Florida', 'Florida']

# %%
two_tables="<h3>Rocket Launch </h3><p><table class='rocket'><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table></p><p><h3>Pizza Party  </h3><table class='pizza'><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td >144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr>"

# %%
two_tables_bs= BeautifulSoup(two_tables, 'html.parser')

# %%
two_tables_bs.find("table")
# Out:
# <table class="rocket"><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table>

# %%
two_tables_bs.find("table",class_='pizza')
# Out:
# <table class="pizza"><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td>144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr></table>

# %%
# Downloading
url = "http://www.ibm.com"

# %%
data = requests.get(url).text

# %%
soup = BeautifulSoup(data, 'html.parser')

# %%
for link in soup.find_all('a', href=True):
    # print(link)
    print(link.get('href'))
# Out:
# https://www.ibm.com/software/data-management?lnk=hpls1us
# https://www.ibm.com/solutions/hybrid-cloud?lnk=hpls2us
# https://www.ibm.com/quantum/blog/international-year-of-quantum?lnk=hprc1us
# https://www.redhat.com/en/about/press-releases/red-hat-nvidia-pair-enterprise-open-source-rack-scale-ai-faster-production-ready-innovation?lnk=hprc2us
# https://www.ibm.com/think/ai-agents?lnk=hprc3us
# https://www.ibm.com/new/product-blog/the-ai-factory-an-enterprise-transformation-engine?lnk=hprc4us
# https://www.ibm.com/case-studies/scuderia-ferrari?lnk=hpcs1us
# https://www.ibm.com/case-studies/avid-solutions-international?lnk=hpcs2us
# https://www.ibm.com/case-studies/pfizer?lnk=hpcs3us
# https://www.ibm.com/case-studies/us-open?lnk=hpcs4us
# https://www.ibm.com/products/offers-and-discounts?lnk=hpdo1us
# https://www.ibm.com/software?lnk=hpfp1us
# https://www.ibm.com/software/ai-productivity?lnk=hpfp2us
# https://www.ibm.com/software/data-management?lnk=hpfp3us
# https://www.ibm.com/software/security-governance?lnk=hpfp4us
# https://www.ibm.com/software/integration-resilience?lnk=hpfp5us
# https://www.ibm.com/software/hybrid-infrastructure-management?lnk=hpfp6us
# https://www.ibm.com/solutions/ai-models?lnk=hpfp7us
# https://www.ibm.com/solutions/analytics?lnk=hpfp8us
# https://www.ibm.com/consulting?lnk=hpfp9us
# https://www.ibm.com/about?lnk=hpii1us
# https://www.ibm.com/history?lnk=hpii1us
# https://research.ibm.com?lnk=hpii1us
# https://www.ibm.com/quantum?lnk=hpii1us
# https://www.ibm.com/careers?lnk=hpii1us
# https://skillsbuild.org?lnk=hpii1us
# https://newsroom.ibm.com/2026-03-18-ibm-fellow-and-quantum-pioneer-charles-h-bennett-receives-a-m-turing-award-computings-highest-honor
# https://newsroom.ibm.com/2026-03-10-ibm-and-lam-research-announce-collaboration-to-advance-sub-1nm-logic-scaling
# https://newsroom.ibm.com/2026-03-09-sei-engages-ibm-to-accelerate-enterprise-transformation-through-agentic-ai
# https://newsroom.ibm.com/2026-03-05-ibm-and-university-researchers-create-a-never-before-seen-molecule-and-prove-its-exotic-nature-with-quantum-computing
# https://newsroom.ibm.com/2026-02-25-ibm-awarded-defense-commissary-agency-contract-to-modernize-electronic-shelf-label-system
# https://newsroom.ibm.com/2026-03-17-ibm-completes-acquisition-of-confluent,-making-real-time-data-the-engine-of-enterprise-ai-and-agents
# https://newsroom.ibm.com/2026-03-16-ibm-and-nvidia-announce-expanded-collaboration-at-gtc-2026-to-advance-ai-for-the-enterprise
# https://newsroom.ibm.com/2026-03-12-ibm-releases-a-new-blueprint-for-quantum-centric-supercomputing

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link)
    print(link.get('src'))
# Out:
# <img alt="Abstract representation of computing system" class="cmp-image__image" height="2501" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/compute_iso_still_master_1x1b?ts=1773822151954&amp;dpr=off" srcset="..." width="2501"/>
# https://assets.ibm.com/is/image/ibm/compute_iso_still_master_1x1b?ts=1773822151954&dpr=off
# <img alt="An abstract representation of Red Hat integration" class="cmp-image__image" height="2345" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/redhat_top_still_master_1x1b?ts=1773822153066&amp;dpr=off" srcset="..." title="Abstract Data Visualization with Circular Interface Element" width="2345"/>
# https://assets.ibm.com/is/image/ibm/redhat_top_still_master_1x1b?ts=1773822153066&dpr=off
# <img alt="An abstract representation of AI strategy" class="cmp-image__image" height="1920" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/12_ai_strategy_plan_iso-1x1-b?ts=1773822167523&amp;dpr=off" srcset="..." title="Futuristic device with circular interface" width="1920"/>
# https://assets.ibm.com/is/image/ibm/12_ai_strategy_plan_iso-1x1-b?ts=1773822167523&dpr=off
# <img alt="An abstract representation of tech management" class="cmp-image__image" height="1920" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/15_techmanage_iso-1x1-b?ts=1773822174576&amp;dpr=off" srcset="..." title="Futuristic data device with blue disc" width="1920"/>
# https://assets.ibm.com/is/image/ibm/15_techmanage_iso-1x1-b?ts=1773822174576&dpr=off
# <img alt="Ferrari logo" class="cmp-image__image" height="1920" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/ferrari-shield-transparent?ts=1773822178607&amp;dpr=off" srcset="..." title="Ferrari emblem with prancing horse design" width="3840"/>
# https://assets.ibm.com/is/image/ibm/ferrari-shield-transparent?ts=1773822178607&dpr=off
# <img alt="Avid Solutions logo" class="cmp-image__image" height="160" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/avid-solutions?ts=1773822181508&amp;dpr=off" srcset="..." title="Avid Solutions Text with Orange Feather Graphic" width="320"/>
# https://assets.ibm.com/is/image/ibm/avid-solutions?ts=1773822181508&dpr=off
# <img alt="Pfizer logo" class="cmp-image__image" height="2591" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/pfizer_logo-1?ts=1773822184440&amp;dpr=off" srcset="..." width="6276"/>
# https://assets.ibm.com/is/image/ibm/pfizer_logo-1?ts=1773822184440&dpr=off
# <img alt="US Open logo" class="cmp-image__image" height="501" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/us-open-logo-2-1-v2-no-margin?ts=1773822187261&amp;dpr=off" srcset="..." title="US Open Tennis Tournament Yellow Ball Logo" width="1002"/>
# https://assets.ibm.com/is/image/ibm/us-open-logo-2-1-v2-no-margin?ts=1773822187261&dpr=off
# <img alt="F1 racer in Ferrari´s team with Ferrari and IBM logo" class="cmp-image__image" height="3840" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/f678_still_f06_v10_zyn_4096x4096?ts=1773822178193&amp;dpr=off" srcset="..." title="Rear view of Formula 1 race car with IBM logo" width="3840"/>
# https://assets.ibm.com/is/image/ibm/f678_still_f06_v10_zyn_4096x4096?ts=1773822178193&dpr=off
# <img alt="Female looking over plants with Avid Solutions logo" class="cmp-image__image" height="1468" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/avid-solutions-leadspace?ts=1773822181168&amp;dpr=off" srcset="..." title="Indoor hydroponic garden with lush greenery" width="3840"/>
# https://assets.ibm.com/is/image/ibm/avid-solutions-leadspace?ts=1773822181168&dpr=off
# <img alt="Pfizer + IBM logos over 3d render of blue molecules" class="cmp-image__image" height="2160" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/pfizer_thumb?ts=1773822184033&amp;dpr=off" srcset="..." title="Pfizer and IBM collaboration visual concept" width="3840"/>
# https://assets.ibm.com/is/image/ibm/pfizer_thumb?ts=1773822184033&dpr=off
# <img alt="Arthur Ashe Stadium, at the US Open 2025" class="cmp-image__image" height="1667" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/ashe-day-1-dustin-satloff_usta-2500pxw?ts=1773822186892&amp;dpr=off" srcset="..." title="Crowded tennis stadium during live match" width="2500"/>
# https://assets.ibm.com/is/image/ibm/ashe-day-1-dustin-satloff_usta-2500pxw?ts=1773822186892&dpr=off
# <img alt="IBM technology solutions illustrated mural representing scalability, accessibility and speed" class="cmp-image__image" height="1536" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/bb4y_5x4?ts=1773822188294&amp;dpr=off" srcset="..." title="Illustration of digital tools and activities" width="1920"/>
# https://assets.ibm.com/is/image/ibm/bb4y_5x4?ts=1773822188294&dpr=off
# <img alt="Illustration of an eye with connecting lines to data" class="cmp-image__image" height="2961" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/watson-discovery_eye-connection_1x1_padding?ts=1773822199232&amp;dpr=off" srcset="..." width="2961"/>
# https://assets.ibm.com/is/image/ibm/watson-discovery_eye-connection_1x1_padding?ts=1773822199232&dpr=off

# %%
#The below url contains an html table with data about colors and color codes.
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %%
soup = BeautifulSoup(data,"html.parser")

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>

# %%
#Get all rows from the table
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].string # store the value in column 3 as color_name
    color_code = cols[3].string # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->None
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF
