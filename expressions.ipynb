# %%
40 + 20 + 10
# Out:
# 70

# %%
50 - 30
# Out:
# 20

# %%
5 * 5
# Out:
# 25

# %%
25 / 5
# Out:
# 5.0

# %%
25 / 6
# Out:
# 4.166666666666667

# %%
25 // 5
# Out:
# 5

# %%
25 // 6
# Out:
# 4

# %%
160 // 60
# Out:
# 2

# %%
30 + 2 * 60
# Out:
# 150

# %%
(30 + 2) * 60
# Out:
# 1920

# %%
x = 4 + 42 + 23

# %%
print (x)
# Out:
# 69

# %%
y = x / 60

# %%
print(y)
# Out:
# 1.15

# %%
x = x / 60
x
# Out:
# 1.15
