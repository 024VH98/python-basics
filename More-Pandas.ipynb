# %%
"""
    It is required to download two files for this module
        - https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/LXjSAttmoxJfEG6il1Bqfw/Product-sales.csv
        - https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n9LOuKI9SlUa1b5zkaCMeg/Product-sales.xlsx
"""
# %pip install xlrd openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [openpyxl]━━━━━━━━━ 2/3 [openpyxl]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pyodide
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [24 lines of output]
#       Traceback (most recent call last):
#         File "/usr/local/lib/python3.14/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 389, in <module>
#           main()
#           ~~~~^^
#         File "/usr/local/lib/python3.14/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/usr/local/lib/python3.14/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 143, in get_requires_for_build_wheel
#           return hook(config_settings)
# ...

# %%
import pandas as pd

# %%
# This doesn't run because we are running Jupyter from local Env
from pyodide.http import pyfetch
import pandas as pd

url =  "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/LXjSAttmoxJfEG6il1Bqfw/Product-sales.csv"
filename = "Product-sales.csv"

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

await download(url, filename)
df = pd.read_csv(filename)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from pyodide.http import pyfetch
#       2 import pandas as pd
#       4 url =  "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/LXjSAttmoxJfEG6il1Bqfw/Product-sales.csv"
#
# ModuleNotFoundError: No module named 'pyodide'

# %%
df = pd.read_csv("Product-sales.csv")

# %%
# Print first five rows of the dataframe

df.head()
# Out:
#    OrderID     Product     Category  Quantity  Price  Total   OrderDate  \
# 0        1      Laptop  Electronics         2    800   1600  2022-01-10
# 1        2  Smartphone  Electronics         3    600   1800  2022-02-15
# 2        3  Desk Chair    Furniture         5    150    750  2022-03-12
# 3        4    Notebook   Stationery        10      2     20  2022-04-05
# 4        5     Monitor  Electronics         1    300    300  2022-05-21
#
#   CustomerCity
# 0     New York
# 1  Los Angeles
# 2      Chicago
# 3      Houston
# 4        Miami

# %%
df = pd.read_excel('Product-sales.xlsx')
df.head()
# Out:
#    OrderID     Product     Category  Quantity  Price  Total  OrderDate  \
# 0        1      Laptop  Electronics         2    800   1600 2022-01-10
# 1        2  Smartphone  Electronics         3    600   1800 2022-02-15
# 2        3  Desk Chair    Furniture         5    150    750 2022-03-12
# 3        4    Notebook   Stationery        10      2     20 2022-04-05
# 4        5     Monitor  Electronics         1    300    300 2022-05-21
#
#   CustomerCity
# 0     New York
# 1  Los Angeles
# 2      Chicago
# 3      Houston
# 4        Miami

# %%
# Access to the column Length

x = df[['Quantity']]
x
# Out:
#    Quantity
# 0         2
# 1         3
# 2         5
# 3        10
# 4         1

# %%
# Get the column as a series

x = df['Product']
x
# Out:
# 0        Laptop
# 1    Smartphone
# 2    Desk Chair
# 3      Notebook
# 4       Monitor
# Name: Product, dtype: str

# %%
# Get the column as a dataframe

x = df[['Quantity']]
type(x)
# Out:
# pandas.DataFrame

# %%
# Access to multiple columns

y = df[['Product','Category', 'Quantity']]
y
# Out:
#       Product     Category  Quantity
# 0      Laptop  Electronics         2
# 1  Smartphone  Electronics         3
# 2  Desk Chair    Furniture         5
# 3    Notebook   Stationery        10
# 4     Monitor  Electronics         1

# %%
# Access the value on the first row and the first column

df.iloc[0, 0]
# Out:
# np.int64(1)

# %%
# Access the value on the second row and the first column

df.iloc[1,0]
# Out:
# np.int64(2)

# %%
# Access the value on the first row and the third column

df.iloc[0,2]
# Out:
# 'Electronics'

# %%
# You can access data using loc
print(df.loc[0, 'Product'])
print(df.loc[1, 'Product'])
print(df.loc[1, 'CustomerCity'])
print(df.loc[1, 'Total'])
# Out:
# Laptop
# Smartphone
# Los Angeles
# 1800

# %%
# Slicing the dataframe

df.iloc[0:2, 0:3]
# Out:
#    OrderID     Product     Category
# 0        1      Laptop  Electronics
# 1        2  Smartphone  Electronics

# %%
# Slicing the dataframe using name

df.loc[0:2, 'OrderID':'Category']
# Out:
#    OrderID     Product     Category
# 0        1      Laptop  Electronics
# 1        2  Smartphone  Electronics
# 2        3  Desk Chair    Furniture

# %%
new_index=['a','b','c','d','e']
# dir(df)
df_new = df
df_new.index = new_index
df_new.loc['a', 'CustomerCity']
# Out:
# 'New York'

# %%
df_new.loc['a':'d', 'CustomerCity']
# Out:
# a       New York
# b    Los Angeles
# c        Chicago
# d        Houston
# Name: CustomerCity, dtype: str
